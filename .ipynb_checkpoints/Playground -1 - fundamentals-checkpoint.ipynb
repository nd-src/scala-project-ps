// %%
a = 5
// Out:
// cmd1.sc:1: not found: value a
// val res1 = a = 5
//            ^
// Compilation Failed

// %%
val a: Int = 5
// Out:
// a: Int = 5

// %%
a = 7
// Out:
// cmd2.sc:1: reassignment to val
// val res2 = a = 7
//              ^
// Compilation Failed

// %%
var b: Int = 4
// Out:
// b: Int = 4

// %%
a + b
// Out:
// res3: Int = 9

// %%
var results: Int = a + b
results
// Out:
// results: Int = 9
// res4_1: Int = 9

// %% [markdown]
// ### Data Structures

// %%
var someArray= Array(1,2,3,4,5)
someArray
// Out:
// someArray: Array[Int] = Array(1, 2, 3, 4, 5)
// res6_1: Array[Int] = Array(1, 2, 3, 4, 5)

// %%
var extract_value = if (!someArray.isEmpty) someArray(0) else someArray(1)
// Out:
// extract_value: Int = 1

// %%
var extract_value = if (!someArray.isEmpty) {
    someArray(0);
} else {
     "Sunday";
}
// Out:
// extract_value: Any = 1

// %%
var extract_value = if (!someArray.isEmpty) {
    someArray(0);
} else "Sunday"
// Out:
// extract_value: Any = 1

// %%
var extract_value = if (!someArray.isEmpty) {
    someArray(0)} else "Sunday"
// Out:
// extract_value: Any = 1

// %%
var aList = List(-1,0,1,2,3,4,5)
// Out:
// aList: List[Int] = List(-1, 0, 1, 2, 3, 4, 5)

// %% [markdown]
// ### For loops

// %%
for (n <- aList) println(n)
// Out:
// -1
// 0
// 1
// 2
// 3
// 4
// 5

// %%
for (n <- aList) {
    if (n < 3) println(n)
}
// Out:
// -1
// 0
// 1
// 2

// %% [markdown]
// #### Double if

// %%
for (a <- aList if a < 2 if a  > 0) println(a)
// Out:
// 1
